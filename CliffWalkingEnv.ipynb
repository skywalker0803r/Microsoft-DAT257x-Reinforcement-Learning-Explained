# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/Microsoft-DAT257x-Reinforcement-Learning-Explained/blob/master/CliffWalkingEnv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sys
from gym.envs.toy_text import discrete

### CliffWalkingEnv Environment 
    
class CliffWalkingEnv(discrete.DiscreteEnv):

    metadata = {'render.modes': ['human', 'ansi', 'rgb_array']}
    
    def _limit_coordinates(self, coord):
        coord[0] = min(coord[0], self.shape[0] - 1)
        coord[0] = max(coord[0], 0)
        coord[1] = min(coord[1], self.shape[1] - 1)
        coord[1] = max(coord[1], 0)
        return coord

    def _calculate_transition_prob(self, current, delta):
        new_position = np.array(current) + np.array(delta)
        new_position = self._limit_coordinates(new_position).astype(int)
        new_state = np.ravel_multi_index(tuple(new_position), self.shape)
        reward = -100.0 if self._cliff[tuple(new_position)] else -1.0
        is_done = self._cliff[tuple(new_position)] or (tuple(new_position) == (3,11))
        return [(1.0, new_state, reward, is_done)]

    def __init__(self):
        self.shape = (4, 12)

        nS = np.prod(self.shape)
        nA = 4

        # Cliff Location
        self._cliff = np.zeros(self.shape, dtype=np.bool)
        self._cliff[3, 1:-1] = True

        # Calculate transition probabilities
        P = {}
        for s in range(nS):
            position = np.unravel_index(s, self.shape)
            P[s] = { a : [] for a in range(nA) }
            #UP = 0
            #RIGHT = 1
            #DOWN = 2
            #LEFT = 3
            P[s][0] = self._calculate_transition_prob(position, [-1, 0])
            P[s][1] = self._calculate_transition_prob(position, [0, 1])
            P[s][2] = self._calculate_transition_prob(position, [1, 0])
            P[s][3] = self._calculate_transition_prob(position, [0, -1])

        # We always start in state (3, 0)
        isd = np.zeros(nS)
        isd[np.ravel_multi_index((3,0), self.shape)] = 1.0

        super(CliffWalkingEnv, self).__init__(nS, nA, P, isd)

    def _convert_state(self, state):
        converted = np.unravel_index(state, self.shape)
        return np.asarray(list(converted), dtype=np.float32)
    
    def reset(self):
        self.s = np.argmax(self.isd)
        return self._convert_state(self.s)
    
    def step(self, action):
        reward = self.P[self.s][action][0][2]
        done = self.P[self.s][action][0][3]
        info = {'prob':self.P[self.s][action][0][0]}
        self.s = self.P[self.s][action][0][1]
        return (self._convert_state(self.s), reward, done, info)
    
    def render(self, mode='rgb_array', close=False):
        if close:
            return

        if mode == 'rgb_array':
            maze = np.zeros((4, 12))
            maze[self._cliff] = -1
            maze[np.unravel_index(self.s, self.shape)] = 2.0
            maze[(3,11)] = 0.5
            img = np.array(maze, copy=True)
            return img
        
        else:
            outfile = StringIO() if mode == 'ansi' else sys.stdout

            for s in range(self.nS):
                position = np.unravel_index(s, self.shape)

                if self.s == s:
                    output = " x "
                elif position == (3,11):
                    output = " T "
                elif self._cliff[position]:
                    output = " C "
                else:
                    output = " o "

                if position[1] == 0:
                    output = output.lstrip() 
                if position[1] == self.shape[1] - 1:
                    output = output.rstrip() 
                    output += "\n"

                outfile.write(output)
            outfile.write("\n")

# %%
env = CliffWalkingEnv()

# %%
import pandas as pd
pd.DataFrame(env.render()).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row1_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row2_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1de43804_10d9_11ea_926e_0242ac1c0002row3_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_1de43804_10d9_11ea_926e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>        <th class="col_heading level0 col10" >10</th>        <th class="col_heading level0 col11" >11</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1de43804_10d9_11ea_926e_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_1de43804_10d9_11ea_926e_0242ac1c0002row0_col5" class="data row0 col5" >0</td>

# %%
env.step(0)
for i in range(11):
  print(env.step(1))
env.step(2)
# Out:
# (array([2., 1.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([2., 2.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([2., 3.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([2., 4.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([2., 5.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([2., 6.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([2., 7.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([2., 8.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([2., 9.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([ 2., 10.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([ 2., 11.], dtype=float32), -1.0, False, {'prob': 1.0})
# (array([ 3., 11.], dtype=float32), -1.0, True, {'prob': 1.0})

# %%
pd.DataFrame(env.render()).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row1_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col7 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col9 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col10 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row2_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_1f75bfee_10d9_11ea_926e_0242ac1c0002row3_col11 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_1f75bfee_10d9_11ea_926e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>        <th class="col_heading level0 col10" >10</th>        <th class="col_heading level0 col11" >11</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1f75bfee_10d9_11ea_926e_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_1f75bfee_10d9_11ea_926e_0242ac1c0002row0_col5" class="data row0 col5" >0</td>
